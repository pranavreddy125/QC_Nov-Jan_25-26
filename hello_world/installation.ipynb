# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.2.3'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
service = QiskitRuntimeService(channel="ibm_cloud",
                               token = 'Qbc24tZyuSU30q6J9QdF_8et2YXaitR7X7O49Hu0rM86')
# Out:
# qiskit_runtime_service._discover_account:WARNING:2025-11-18 15:22:31,809: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2025-11-18 15:22:35,473: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().

# %%
QiskitRuntimeService.save_account(channel="ibm_cloud",
                                  token='Qbc24tZyuSU30q6J9QdF_8et2YXaitR7X7O49Hu0rM86')

# %%
backend = service.backend(name = "ibm_torino")
# Out:
# qiskit_runtime_service.backends:WARNING:2025-11-18 15:30:12,887: Using instance: open-instance, plan: open

# %%
backend.num_qubits
# Out:
# 133
