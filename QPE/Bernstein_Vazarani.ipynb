# %% [markdown]
# Bernstein Vazarani algo proof, applying notes to code with Qiskit
# Code flow: 1 qubit for each bit in string + 1 extra (to create phase)
#     Extra qubit prepared to be an eigenstate of the target operation (so effect of oracle shows up as phase on the control qubit)
